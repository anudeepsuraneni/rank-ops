# %%
import pandas as pd 
ratings = pd.read_csv("../data/raw/ml-25m/ratings.csv")
print(ratings.shape)
print(ratings.dtypes)
ratings.head()
# Out:
# (25000095, 4)
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
import duckdb

# read the schema SQL and execute it in an in-memory DuckDB
sql = open("../sql/schema.sql").read()
conn = duckdb.connect(database=":memory:")

sessions_df = conn.execute(sql).df()
print("sessions:", sessions_df.shape)
sessions_df.head()
# Out:
# sessions: (25000095, 4)
#    user_id  item_id   timestamp  session_id
# 0      791     7153  1515175235         1.0
# 1      791     5952  1515175255         1.0
# 2      791     4993  1515175301         1.0
# 3      791    68954  1515175307         1.0
# 4      791   134853  1515175326         1.0
